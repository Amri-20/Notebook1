# %%
import pandas as pd
import numpy as np
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
train=pd.read_csv("train.csv")
public_test=pd.read_csv("public_test.csv")
private_test=pd.read_csv("private_test.csv")

# %%
train.head()
# Out:
#    User_ID   Age         Income  City_Tier Device_Type Traffic_Source  \
# 0        1  58.0  103593.708812          2      Mobile        Organic
# 1        2  26.0   36451.716984          2      Mobile   Social Media
# 2        3  19.0   30511.228700          3      Mobile       Referral
# 3        4  48.0   87789.172342          3      Mobile          Email
# 4        5  35.0  105229.249067          2      Mobile   Social Media
#
#    Pages_Viewed  Products_Viewed  Time_On_Site  Previous_Purchases  \
# 0             5                4          9.61                   3
# 1            11                3         17.63                   2
# 2             1                1         13.25                   5
# 3            14               12           NaN                   1
# 4            14               21         16.92                   1
#
#    Discount_Seen  Browser_Version  Campaign_Code  Converted
# 0              0               11           2418          0
# ...

# %%
print(train.shape)
print(public_test.shape)
print(private_test.shape)
# Out:
# (10000, 14)
# (3000, 14)
# (3000, 13)

# %%
train.isnull().sum()
# Out:
# User_ID                  0
# Age                   1480
# Income                 984
# City_Tier                0
# Device_Type              0
# Traffic_Source           0
# Pages_Viewed             0
# Products_Viewed          0
# Time_On_Site          1848
# Previous_Purchases       0
# Discount_Seen            0
# Browser_Version          0
# Campaign_Code            0
# Converted                0
# dtype: int64

# %%
train["Converted"].value_counts()
# Out:
# Converted
# 0    6913
# 1    3087
# Name: count, dtype: int64

# %%
for col in ["Age", "Income", "Time_On_Site"]:
    pct = train[col].isnull().mean() * 100
    print(col, round(pct, 2), "%")
# Out:
# Age 14.8 %
# Income 9.84 %
# Time_On_Site 18.48 %

# %%
train['Age']=train['Age'].fillna(train["Age"]).median()
train['Income']=train['Income'].fillna(train["Income"]).median()
train['Time_On_Site']=train['Time_On_Site'].fillna(train["Time_On_Site"]).median()

# %%
train.isnull().sum()
# Out:
# User_ID               0
# Age                   0
# Income                0
# City_Tier             0
# Device_Type           0
# Traffic_Source        0
# Pages_Viewed          0
# Products_Viewed       0
# Time_On_Site          0
# Previous_Purchases    0
# Discount_Seen         0
# Browser_Version       0
# Campaign_Code         0
# Converted             0
# dtype: int64

# %%
x=train.drop(["User_ID","Campaign_Code","Converted"],axis=1)
y=train["Converted"]

# %%
x.duplicated().sum()
# Out:
# np.int64(23)

# %%
chg_col=["City_Tier","Device_Type","Traffic_Source","Browser_Version","Campaign_Code"]

# %%
for col in chg_col:
    le=LabelEncoder()

    train[col]=le.fit_transform(
        train[col].astype(str)
    )
